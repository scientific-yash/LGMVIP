# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
image = cv.imread("img.jpg")

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=495x348 at 0x7F2715BF62D0>

# %%
gray_image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)

# %%
inverted = 255-gray_image

# %%
blur = cv.GaussianBlur(inverted, (21, 21), 0)

# %%
invertedblur = 255-blur

# %%
sketch = cv.divide(gray_image, invertedblur, scale=256.0)

# %%
cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=L size=495x348 at 0x7F2715BF40D0>

# %%
cv. waitKey(0)
# Out:
# -1
